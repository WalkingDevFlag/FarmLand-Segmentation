# %%
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()
import numpy as np
import os
import cv2
import rasterio
import matplotlib.pyplot as plt
from shapely.geometry import Polygon
import geopandas as gpd
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer, ColorMode

# %%
# Configuration setup
cfg = get_cfg()
cfg.OUTPUT_DIR = r"E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\Models\model_50000_epochs (7.5k)"
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 2  # Update if needed
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.2
#cfg.MODEL.ROI_HEADS.NMS_THRESH_TEST = 0.5
predictor = DefaultPredictor(cfg)
# Out:
# [07/23 17:57:03 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\Models\model_50000_epochs (7.5k)\model_final.pth ...

# %%
# Directory paths
input_dir = r"E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\GeoRef Data"  # Change to your input directory
output_dir = r"E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images"  # Change to your output directory
shapefile_dir = r"E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result"  # Change to your shapefile output directory

# Ensure output directories exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(shapefile_dir):
    os.makedirs(shapefile_dir)

# %%
def read_tiff(file_path):
    with rasterio.open(file_path) as src:
        image = src.read([1, 2, 3])  # Read RGB bands
        image = image.transpose((1, 2, 0))  # Reorder dimensions
    return image

# %%
def display_image(image, title="Image"):
    plt.figure(figsize=(8, 8))
    plt.imshow(image)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
def predict_and_save(file_path, output_image_path):
    # Read TIFF file
    image = read_tiff(file_path)
    
    # Perform inference
    outputs = predictor(image)
    
    # Visualize results
    v = Visualizer(image[:, :, ::-1], instance_mode=ColorMode.SEGMENTATION)
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    
    # Save the segmented image
    segmented_image = out.get_image()[:, :, ::-1]
    cv2.imwrite(output_image_path, cv2.cvtColor(segmented_image, cv2.COLOR_RGB2BGR))
    
    print(f"Segmented image saved to: {output_image_path}")

# %%
def create_polygons_from_masks(masks, transform):
    polygons = []
    for mask in masks:
        mask = mask.numpy()
        contours, _ = cv2.findContours(mask.astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        for contour in contours:
            if len(contour) >= 3:  # valid polygon must have at least 3 points
                poly_points = [transform * (point[0], point[1]) for point in contour.squeeze()]
                polygon = Polygon(poly_points)
                
                # Check if the polygon is valid
                if not polygon.is_valid:
                    polygon = polygon.buffer(0)  # Attempt to repair invalid polygons
                
                polygons.append(polygon)
    return polygons

# %%
def handle_overlapping_polygons(polygons):
    updated_polygons = []
    
    for poly in polygons:
        # Check if the polygon is valid
        if not poly.is_valid:
            poly = poly.buffer(0)  # Attempt to repair invalid polygons
        
        for existing_poly in updated_polygons:
            # Check if the existing polygon is valid
            if not existing_poly.is_valid:
                existing_poly = existing_poly.buffer(0)  # Attempt to repair invalid polygons
                
            if poly.intersects(existing_poly):
                intersection = poly.intersection(existing_poly)
                intersection_area = intersection.area
                poly_area = poly.area
                existing_poly_area = existing_poly.area

                if intersection_area / poly_area > 0.5 or intersection_area / existing_poly_area > 0.5:
                    if poly_area > existing_poly_area:
                        poly = poly.union(existing_poly)
                        updated_polygons.remove(existing_poly)
                    else:
                        existing_poly = existing_poly.union(poly)
                        poly = existing_poly
                
                elif intersection_area / poly_area <= 0.5 and intersection_area / existing_poly_area <= 0.5:
                    if poly_area > existing_poly_area:
                        poly = poly.difference(existing_poly)
                    else:
                        existing_poly = existing_poly.difference(poly)
                        
        updated_polygons.append(poly)

    return updated_polygons

# %%
def create_shapefile_from_predictions(outputs, shapefile_folder, shapefile_base_name, transform, crs):
    pred_masks = outputs["instances"].pred_masks.to("cpu")
    polygons = create_polygons_from_masks(pred_masks, transform)
    polygons = handle_overlapping_polygons(polygons)
    
    # Check if there are valid polygons to save
    if not polygons:
        print(f"No valid polygons found for {shapefile_base_name}. Skipping shapefile creation.")
        return
    
    gdf = gpd.GeoDataFrame(geometry=polygons, crs=crs)
    
    # Create directory for shapefile
    os.makedirs(shapefile_folder, exist_ok=True)
    
    # Save shapefile
    shapefile_path = os.path.join(shapefile_folder, shapefile_base_name + ".shp")
    gdf.to_file(shapefile_path)
    
    print(f"Shapefile created: {shapefile_path}")

# %%
def process_tiff_files(input_dir, output_dir, shapefile_dir):
    tiff_files = [f for f in os.listdir(input_dir) if f.lower().endswith(('.tiff', '.tif', '.TIF', '.TIFF'))]

    for file_name in tiff_files:
        file_path = os.path.join(input_dir, file_name)
        output_image_path = os.path.join(output_dir, file_name.replace('.tiff', '.jpg').replace('.tif', '.jpg').replace('.TIFF', '.jpg').replace('.TIF', '.jpg'))
        shapefile_folder = os.path.join(shapefile_dir, os.path.splitext(file_name)[0])
        base_name = os.path.splitext(file_name)[0]

        # Read image for transform and crs
        with rasterio.open(file_path) as src:
            transform = src.transform
            crs = src.crs

        # Predict and save segmented image
        predict_and_save(file_path, output_image_path)
        
        # Perform prediction again to get the outputs for shapefile creation
        image = read_tiff(file_path)
        outputs = predictor(image)
        
        # Create shapefile from predictions
        create_shapefile_from_predictions(outputs, shapefile_folder, base_name, transform, crs)

# %%
# Run the processing
process_tiff_files(input_dir, output_dir, shapefile_dir)

print("Processing complete. Segmented images and shapefiles saved.")
# Out:
# C:\Users\Siddharth\anaconda3\envs\detectron_env\lib\site-packages\torch\functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:3588.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a0.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a0\a0.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a1.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a1\a1.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a10.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a10\a10.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a100.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a100\a100.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a101.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a101\a101.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a102.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a102\a102.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a103.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a103\a103.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a104.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a104\a104.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a105.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a105\a105.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a106.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a106\a106.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a107.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a107\a107.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a108.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a108\a108.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a109.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a109\a109.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a11.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a11\a11.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a110.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a110\a110.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a111.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a111\a111.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a112.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a112\a112.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a113.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a113\a113.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a114.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a114\a114.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a115.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a115\a115.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a116.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a116\a116.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a117.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a117\a117.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a118.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a118\a118.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a119.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a119\a119.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a12.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a12\a12.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a120.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a120\a120.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a121.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a121\a121.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a122.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a122\a122.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a123.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a123\a123.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a124.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a124\a124.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a125.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a125\a125.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a126.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a126\a126.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a127.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a127\a127.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a128.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a128\a128.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a129.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a129\a129.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a13.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a13\a13.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a130.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a130\a130.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a131.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a131\a131.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a132.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a132\a132.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a133.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a133\a133.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a134.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a134\a134.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a135.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a135\a135.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a136.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a136\a136.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a137.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a137\a137.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a138.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a138\a138.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a139.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a139\a139.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a14.jpg
# No valid polygons found for a14. Skipping shapefile creation.
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a140.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a140\a140.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a141.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a141\a141.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a142.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a142\a142.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a143.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a143\a143.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a144.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a144\a144.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a145.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a145\a145.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a146.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a146\a146.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a147.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a147\a147.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a148.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a148\a148.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a149.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a149\a149.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a15.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a15\a15.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a150.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a150\a150.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a151.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a151\a151.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a152.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a152\a152.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a153.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a153\a153.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a154.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a154\a154.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a155.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a155\a155.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a156.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a156\a156.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a157.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a157\a157.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a158.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a158\a158.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a159.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a159\a159.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a16.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a16\a16.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a160.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a160\a160.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a161.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a161\a161.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a162.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a162\a162.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a163.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a163\a163.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a164.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a164\a164.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a165.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a165\a165.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a166.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a166\a166.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a167.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a167\a167.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\a168.jpg
# Shapefile created: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\result\a168\a168.shp
# Segmented image saved to: E:\Random Python Scripts\FarmLand-Segmentation-main\Detectron 2\infer 2.0 trial\predicted images\